# %% [markdown]
# # PROJECT-PHASE-3

# %% [markdown]
# # STUDENTS-GRADE-PREDICTION

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Downloading the dataset from Github to my PC and and in jupyter notebook using pd.read_csv

# %%
df=pd.read_csv("student_grades.csv")
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# # EXPLANATORY DATA ANALYSIS

# %%
df.shape
# Out:
# (1044, 33)

# %% [markdown]
# The dataset has 1044 rows and 33 columns

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.tail()
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
#       ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 1039  ...      5        4      2     1     2      5        4  10  11  10
# 1040  ...      4        3      4     1     1      1        4  15  15  16
# 1041  ...      1        1      1     1     1      5        6  11  12   9
# 1042  ...      2        4      5     3     4      2        6  10  10  10
# 1043  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
df.columns #features/independent variables.
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
# ...

# %% [markdown]
# There are 1044 rows and 33 columns out of which G3 is the target variable. We have object and integer datatypes.
# Memory usage is 269.3+KB. Range is 0 to 1043

# %%
df.columns.to_list()
# Out:
# ['school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %% [markdown]
# Attributes or independent variables are 32 columns and dependent variable/label/target is G3.
# Features are age, sex, school, address, family size, health, abscences, holiday day, travel time, study time, etc.

# %%
df.nunique().to_frame("Students_Grades")
# Out:
#             Students_Grades
# school                    2
# sex                       2
# age                       8
# address                   2
# famsize                   2
# Pstatus                   2
# Medu                      5
# Fedu                      5
# Mjob                      5
# Fjob                      5
# reason                    4
# guardian                  3
# traveltime                4
# studytime                 4
# failures                  4
# schoolsup                 2
# famsup                    2
# paid                      2
# activities                2
# nursery                   2
# higher                    2
# internet                  2
# romantic                  2
# famrel                    5
# freetime                  5
# goout                     5
# Dalc                      5
# Walc                      5
# health                    5
# absences                 35
# G1                       18
# G2                       17
# ...

# %%
df['G3'].nunique()
# Out:
# 19

# %% [markdown]
# # There ar 19 unique values as compared to the total rows of 1044. There is a class difference here. So clearly this is classification problem.

# %%
#checking for null values
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are no null values present here as the color is uniform

# %%
for i in df:
    print(df[i].value_counts)
    print("\n")
# Out:
# <bound method IndexOpsMixin.value_counts of 0       GP
# 1       GP
# 2       GP
# 3       GP
# 4       GP
#         ..
# 1039    MS
# 1040    MS
# 1041    MS
# 1042    MS
# 1043    MS
# Name: school, Length: 1044, dtype: object>
#
#
# <bound method IndexOpsMixin.value_counts of 0       F
# 1       F
# 2       F
# 3       F
# 4       F
#        ..
# 1039    F
# 1040    F
# 1041    F
# 1042    M
# 1043    M
# Name: sex, Length: 1044, dtype: object>
#
#
# <bound method IndexOpsMixin.value_counts of 0       18
# 1       17
# 2       15
# 3       15
# 4       16
#         ..
# 1039    19
# 1040    18
# 1041    18
# 1042    17
# 1043    18
# Name: age, Length: 1044, dtype: int64>
#
#
# <bound method IndexOpsMixin.value_counts of 0       U
# 1       U
# 2       U
# 3       U
# 4       U
#        ..
# 1039    R
# 1040    U
# 1041    U
# 1042    U
# 1043    R
# Name: address, Length: 1044, dtype: object>
#
#
# <bound method IndexOpsMixin.value_counts of 0       GT3
# 1       GT3
# ...

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %%
Observations:
    1. All row counts are equal which shows no missing values.
    2. There are no negative values in the dataset, which is good.
    3. Standard deviaiton: Only few columns have a minor value of SD.
    4. Mean is greater than median for age, Fedu, failures, freetime, goout, Dalc, Walc, abscenses, G1, G2, G3. All these have
    right-ward skewness. Other columns have left-ward skewness.
    5. Outliers: Fedu, famrel, and health do not have outliers as both max and 75% values are same. For other columns,
        there are outliers present.
    6. Mim values for age is 15. Medu, Fedu, failures, absences, G1, G2, G3 have 0 values. others have 1 as min value.
       Similarly we can also find 25% values also.

# %%
plt.figure(figsize=(22, 10))
sns.heatmap(df.describe(), annot=True, fmt='0.2f', linewidth=0.2, linecolor='black', cmap='Dark2')
plt.xlabel('Figure', fontsize=14)
plt.ylabel("Featuire_name', fontsize=20")
plt.title("Descriptive Graph", fontsize=30)
plt.show()

# %% [markdown]
# The sns heatmap also gives the same values as df.describe() method.

# %% [markdown]
# # Dividing data into numerical and categorical columns

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical columns:", categorical_col)
# Out:
# Categorical columns: ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']

# %%
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical columns:", numerical_col)
# Out:
# Numerical columns: ['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']

# %% [markdown]
# # GRAPHICAL ANALYSIS

# %% [markdown]
# # Univariate Analysis with countplots

# %%
sns.countplot(x="G3", data=df)
plt.xlabel("Grade 3 Counts")
plt.title("Grades")
df['G3'].value_counts()
# Out:
# 10    153
# 11    151
# 13    113
# 12    103
# 14     90
# 15     82
# 8      67
# 9      63
# 0      53
# 16     52
# 17     35
# 18     27
# 7      19
# 6      18
# 5       8
# 19      7
# 20      1
# 4       1
# 1       1
# Name: G3, dtype: int64

# %% [markdown]
# From the graph, we can note that grade3 10 has been acheived by maximum students followed by 11. minimum grades are 1, 4, and 20.

# %%
sns.countplot(x="G1", data=df)
plt.xlabel("G1 grade")
plt.title("G1")
# Out:
# Text(0.5, 1.0, 'G1')

# %% [markdown]
# We can see that here also 10 is the grade which is max in G1 column followed by 11. Minimum grades are 0, 3,4, and 19.

# %%
sns.countplot(x="G2", data=df)
plt.xlabel("G2 grades")
plt.title("G2")
# Out:
# Text(0.5, 1.0, 'G2')

# %%
sns.countplot(x="sex", data=df)
plt.xlabel("sex")
plt.title("Both male and female Children")
# Out:
# Text(0.5, 1.0, 'Both male and female Children')

# %% [markdown]
# Majority of students were females as compared to males.

# %%
sns.countplot(x="age", data=df)
plt.xlabel("age")
plt.title("Ages of Children")
# Out:
# Text(0.5, 1.0, 'Ages of Children')

# %% [markdown]
# Maximum age of students was 17 but age group of 16 were more in number. The ranges of age were from 15 to 22, 22 being the
# minimum amount of students.

# %%
sns.countplot(x="health", data=df)
plt.xlabel("health")
plt.title("Health of Children")
# Out:
# Text(0.5, 1.0, 'Health of Children')

# %% [markdown]
# Here 5 has major number of count followed by least at 2.

# %%
plt.figure(figsize=[20, 25])
plotnumber=1
for i in df.columns:
    if plotnumber<=43:
        plt.subplot(8, 5, plotnumber)
        sns.countplot(x=i, data=df)
    plotnumber+=1
plt.show()

# %% [markdown]
# We can see count plots of all the variables.

# %% [markdown]
# Kernel Density plots for distribution of data

# %%
sns.kdeplot(df['G3'])
# Out:
# <AxesSubplot:xlabel='G3', ylabel='Density'>

# %% [markdown]
# There is almos a normal distribution of data in G3 column.

# %%
df.hist(bins=20, figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'Medu'}>,
#         <AxesSubplot:title={'center':'Fedu'}>,
#         <AxesSubplot:title={'center':'traveltime'}>],
#        [<AxesSubplot:title={'center':'studytime'}>,
#         <AxesSubplot:title={'center':'failures'}>,
#         <AxesSubplot:title={'center':'famrel'}>,
#         <AxesSubplot:title={'center':'freetime'}>],
#        [<AxesSubplot:title={'center':'goout'}>,
#         <AxesSubplot:title={'center':'Dalc'}>,
#         <AxesSubplot:title={'center':'Walc'}>,
#         <AxesSubplot:title={'center':'health'}>],
#        [<AxesSubplot:title={'center':'absences'}>,
#         <AxesSubplot:title={'center':'G1'}>,
#         <AxesSubplot:title={'center':'G2'}>,
#         <AxesSubplot:title={'center':'G3'}>]], dtype=object)

# %% [markdown]
# Histogram graph shows normal curves for G1, G2 and G3, Fedu, Medu, goout and even age. Right-skewed curves for absences, Dalc,
# Walc, failures, and traveltime. Right-ward skewed curves for health and famrel.

# %%
plt.figure(figsize=(15, 15))
plotnumber=1
for col in numerical_col:
    if plotnumber<=43:
        plt.subplot(8, 5, plotnumber)
        df.boxplot(col)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Checking Zscore values

# %%
from scipy.stats import zscore

# %%
attributes=df[['age', 'traveltime', 'studytime', 'failures', 'famrel', 'freetime', 'studytime','Dalc', 'absences', 'G1','G2', 'G3']]

# %%
z=np.abs(zscore(attributes))
z
# Out:
#            age  traveltime  studytime  failures    famrel  freetime  \
# 0     1.027889    0.652210   0.035606  0.403106  0.068788  0.195099
# 1     0.221035    0.715074   0.035606  0.403106  1.140653  0.195099
# 2     1.392674    0.715074   0.035606  4.171268  0.068788  0.195099
# 3     1.392674    0.715074   1.234713  0.403106  1.003076  1.165019
# 4     0.585820    0.715074   0.035606  0.403106  0.068788  0.195099
# ...        ...         ...        ...       ...       ...       ...
# 1039  1.834744    0.715074   1.234713  1.121686  1.140653  0.774821
# 1040  1.027889    0.715074   0.035606  0.403106  0.068788  0.195099
# 1041  1.027889    0.652210   0.035606  0.403106  3.146806  2.134939
# 1042  0.221035    0.652210   1.163502  0.403106  2.074941  0.774821
# 1043  1.027889    2.019494   1.163502  0.403106  0.068788  0.774821
#
#       studytime      Dalc  absences        G1        G2        G3
# 0      0.035606  0.542374  0.252155  2.083727  1.597738  1.382871
# ...

# %%
np.where(z>3)
# Out:
# (array([   2,   18,   25,   29,   40,   61,   61,   66,   66,   74,   78,
#          100,  103,  108,  108,  127,  130,  131,  134,  134,  135,  136,
#          137,  144,  144,  146,  149,  149,  150,  153,  153,  157,  162,
#          164,  164,  173,  183,  184,  198,  205,  206,  207,  223,  228,
#          236,  242,  244,  247,  247,  247,  269,  276,  280,  299,  307,
#          315,  327,  327,  332,  349,  350,  357,  375,  389,  392,  392,
#          395,  413,  420,  424,  456,  456,  461,  461,  473,  495,  503,
#          503,  526,  531,  533,  536,  538,  545,  545,  557,  564,  565,
#          573,  574,  592,  593,  607,  616,  632,  632,  637,  645,  651,
#          657,  674,  674,  674,  694,  739,  764,  774,  774,  780,  802,
#          808,  808,  823,  828,  829,  835,  840,  842,  848,  849,  852,
#          853,  854,  873,  886,  895,  897,  918,  922,  925,  934,  938,
#          952,  958,  958,  962,  963,  966,  971,  977,  992,  993,  996,
# ...

# %%
z.iloc[2, 3] #zscore >4.
# Out:
# 4.171268129332915

# %%
df1=df[(z<3).all(axis=1)] #

# %%
df1.shape
# Out:
# (917, 33)

# %%
df.shape
# Out:
# (1044, 33)

# %%
print("Old DataFrame:", df.shape[0])
print("New DataFrame:", df1.shape[0])
print("Dataloss percentage:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Old DataFrame: 1044
# New DataFrame: 917
# Dataloss percentage: 12.164750957854405

# %%
There is 12% data loss here.

# %%
q1=attributes.quantile(0.25)
q3=attributes.quantile(0.75)
IQR=q3-q1

# %%
#Could not find IQR

# %%
df=df1

# %% [markdown]
# # Bivariate analysis

# %%
plt.figure(figsize=(20, 25))
p=1
for i in categorical_col:
    if p<=13:
        plt.subplot(5, 4 , p)
        sns.scatterplot(x='G3', y=i, data=df, palette ='bright')
        plt.xlabel('G3')
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# Scatter plot gives the distribution of categorical data. The first columns shows the values of schools. Second for sex
# and third for address. Guardians column shows mother has more points than others. Activities almost have same counts.

# %%
plt.figure(figsize=(20, 25))
p=1
for i in df[numerical_col]:
    if p<=13:
        plt.subplot(5,4,p)
        sns.regplot(x='G3',y = i, data=df, color='r')
        plt.xlabel(i)
        plt.ylabel('G3')
    p+=1
plt.show()

# %% [markdown]
# AGe, traveltime, failures, Dalc, Walc , freetime and absences are negatively correlated to the target G3.
# Medu, Fedu, studytime, familytime all are postively related to G3, which means these features add to the score of G3.

# %% [markdown]
# # Linear Model Plots

# %%
sns.lmplot(x='studytime', y='G3', data=df, palette='colorblind') #AS studytime increases, G3 increases, +ve correlation

# %%
sns.lmplot(x='goout', y='G3', data=df, palette='colorblind')# As goout time increases, G3 decreases. -vely related.

# %%
sns.lmplot(x='Medu', y='G3', data=df, palette='colorblind')# As mothers education increases, G3 also incresaes, shwoing +ve relation.

# %%
sns.lmplot(x='G1', y='G3', hue='sex', data=df, palette='colorblind')

# %% [markdown]
# We can see that as G1 increases, G3 also increases and male students are majority in number.

# %%
sns.lmplot(x='G2', y='G3', hue='sex', data=df, palette='colorblind')

# %% [markdown]
# The same case as above. AS G2 increases, G3 also increases, which is a contributor to the data

# %%
sns.countplot(x='G3', hue='sex', data=df)
# Out:
# <AxesSubplot:xlabel='G3', ylabel='count'>

# %% [markdown]
# # Bar plot

# %%
sns.barplot(x = 'Fedu', y ='G3', data =df)
plt.ylabel('G3')
plt.title('G3 by Fedu')
# Out:
# Text(0.5, 1.0, 'G3 by Fedu')

# %% [markdown]
# Here G3 remains same as Fathers education  increases. Not much of a difference

# %% [markdown]
# # Stripplot

# %%
plt.title("comparison between health and studytime")
sns.stripplot(x='health', y='studytime', hue='sex', data=df)
plt.show()

# %%
Male students are a high number here.

# %%
df.skew()
# Out:
# age           0.260888
# Medu         -0.175550
# Fedu          0.052189
# traveltime    1.072187
# studytime     0.640819
# failures      2.700080
# famrel       -0.566037
# freetime     -0.199384
# goout         0.054888
# Dalc          1.905505
# Walc          0.606022
# health       -0.494060
# absences      1.542063
# G1            0.091061
# G2            0.107334
# G3           -0.916875
# dtype: float64

# %%
df['traveltime']=np.cbrt(df['traveltime'])
df['failures']=np.cbrt(df['failures'])
df['Dalc']=np.cbrt(df['Dalc'])
df['Walc']=np.cbrt(df['Walc'])
df['absences']=np.cbrt(df['absences'])
df['studytime']=np.cbrt(df['studytime'])

# %%
df['failures']=np.sqrt(df['failures'])#again tried reducing with sqrt for failure and Dalc
df['Dalc']=np.sqrt(df['Dalc'])

# %%
df.skew()
# Out:
# age           0.260888
# Medu         -0.175550
# Fedu          0.052189
# traveltime    0.824508
# studytime     0.074386
# failures      2.096120
# famrel       -0.566037
# freetime     -0.199384
# goout         0.054888
# Dalc          1.440277
# Walc          0.232364
# health       -0.494060
# absences     -0.180093
# G1            0.091061
# G2            0.107334
# G3           -0.916875
# dtype: float64

# %% [markdown]
# There is reduction in all the skewed columns

# %%
plt.figure (figsize=(20, 25), facecolor='green')
plotnumber=1
for column in numerical_col:
    if plotnumber<=18:
        ax=plt.subplot(6,4, plotnumber)
        sns.distplot(df[column], color='b')
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# We can see a normalized curve for all the variables after reduction in skewness

# %% [markdown]
# # Correlation with the variables.

# %%
df.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.115193 -0.104402    0.084043   0.040627  0.284777
# Medu       -0.115193  1.000000  0.629047   -0.208618   0.093187 -0.192026
# Fedu       -0.104402  0.629047  1.000000   -0.172653   0.020860 -0.158360
# traveltime  0.084043 -0.208618 -0.172653    1.000000  -0.115439  0.103793
# studytime   0.040627  0.093187  0.020860   -0.115439   1.000000 -0.113006
# failures    0.284777 -0.192026 -0.158360    0.103793  -0.113006  1.000000
# famrel     -0.002419  0.033593  0.013742   -0.039816   0.058806 -0.054893
# freetime   -0.009876 -0.000878  0.012309   -0.017900  -0.060640  0.081355
# goout       0.130145  0.041223  0.046665   -0.011992  -0.045900  0.061294
# Dalc        0.098905  0.014070  0.007747    0.073122  -0.199219  0.156352
# Walc        0.119735 -0.020887  0.032435    0.027777  -0.241431  0.090950
# health     -0.024650 -0.007121  0.035152   -0.053356  -0.072718  0.056123
# ...

# %%
corr_hmap=df.corr()
plt.figure(figsize=(12, 11))
sns.heatmap(corr_hmap, annot=True, fmt='0.2f', cmap='Spectral')
plt.xlabel("Figure", fontsize=15)
plt.ylabel("Feature Names", fontsize=15)
plt.title("Descriptive Graph", fontsize=20)
plt.show()

# %%
The df.corr() method and heatmap suggests that age is -vely correlated with G2 and G3 with same values and is not at all
related to famrel. Age is positively related to traveltime, health, Dalc, Walc.
Medu is +vely related to G1 and G2 with same values showing multicollinearity issue. Dalc is +vely related to Medu and Fedu 
to same values. Similarly absenses also has multicolinearity issue. Most of the features have multicollinearity issue.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
le=LabelEncoder()
for i in categorical_col:
    df[i]=le.fit_transform(df[i])
df
# Out:
#       school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0          0    0   18        1        0        0     4     4     0     4
# 1          0    0   17        1        0        1     1     1     0     2
# 3          0    0   15        1        0        1     4     2     1     3
# 4          0    0   16        1        0        1     3     3     2     2
# 5          0    1   16        1        1        1     4     3     3     2
# ...      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...
# 1038       1    0   18        0        0        1     4     4     4     0
# 1039       1    0   19        0        0        1     2     3     3     2
# 1040       1    0   18        1        1        1     3     1     4     3
# 1042       1    1   17        1        1        1     3     1     3     3
# 1043       1    1   18        0        1        1     3     2     3     2
#
#       ...  famrel  freetime  goout      Dalc      Walc  health  absences  G1  \
# ...

# %%
x=df.iloc[:,:-1]
x
# Out:
#       school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0          0    0   18        1        0        0     4     4     0     4
# 1          0    0   17        1        0        1     1     1     0     2
# 3          0    0   15        1        0        1     4     2     1     3
# 4          0    0   16        1        0        1     3     3     2     2
# 5          0    1   16        1        1        1     4     3     3     2
# ...      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...
# 1038       1    0   18        0        0        1     4     4     4     0
# 1039       1    0   19        0        0        1     2     3     3     2
# 1040       1    0   18        1        1        1     3     1     4     3
# 1042       1    1   17        1        1        1     3     1     3     3
# 1043       1    1   18        0        1        1     3     2     3     2
#
#       ...  romantic  famrel  freetime  goout      Dalc      Walc  health  \
# ...

# %%
st=StandardScaler() #scaling applied and we can see the uniformity in the values
x=pd.DataFrame(st.fit_transform(x))
x
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.578609 -0.862175  1.114792  0.602126 -0.649389 -2.811212  1.213436
# 1   -0.578609 -0.862175  0.274114  0.602126 -0.649389  0.355718 -1.461374
# 2   -0.578609 -0.862175 -1.407242  0.602126 -0.649389  0.355718  1.213436
# 3   -0.578609 -0.862175 -0.566564  0.602126 -0.649389  0.355718  0.321833
# 4   -0.578609  1.159857 -0.566564  0.602126  1.539910  0.355718  1.213436
# ..        ...       ...       ...       ...       ...       ...       ...
# 912  1.728281 -0.862175  1.114792 -1.660782 -0.649389  0.355718  1.213436
# 913  1.728281 -0.862175  1.955471 -1.660782 -0.649389  0.355718 -0.569770
# 914  1.728281 -0.862175  1.114792  0.602126  1.539910  0.355718  0.321833
# 915  1.728281  1.159857  0.274114  0.602126  1.539910  0.355718  0.321833
# 916  1.728281  1.159857  1.114792 -1.660782  1.539910  0.355718  0.321833
#
#            7         8         9   ...        22        23        24  \
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF["VIF values"]=[variance_inflation_factor(x.values, i) for i in range (len(x.columns))]
VIF["features"]=x.columns
VIF
# Out:
#     VIF values  features
# 0     1.441889         0
# 1     1.323529         1
# 2     1.338948         2
# 3     1.307322         3
# 4     1.113350         4
# 5     1.136181         5
# 6     2.167487         6
# 7     1.793248         7
# 8     1.423072         8
# 9     1.136763         9
# 10    1.087476        10
# 11    1.158800        11
# 12    1.235942        12
# 13    1.293687        13
# 14    1.328989        14
# 15    1.184069        15
# 16    1.145607        16
# 17    1.105740        17
# 18    1.126227        18
# 19    1.063807        19
# 20    1.197226        20
# 21    1.160651        21
# 22    1.103120        22
# 23    1.098829        23
# 24    1.204893        24
# 25    1.356568        25
# 26    1.654236        26
# 27    1.897795        27
# 28    1.104825        28
# 29    1.147610        29
# 30    5.553532        30
# 31    5.544984        31

# %% [markdown]
# VIF is not showing multicollinearity issue in any of the columns. All have a value less than 10.

# %%
y=df.iloc[:,-1]
y
# Out:
# 0        6
# 1        6
# 3       15
# 4       10
# 5       15
#         ..
# 1038    10
# 1039    10
# 1040    16
# 1042    10
# 1043    11
# Name: G3, Length: 917, dtype: int64

# %% [markdown]
# # Installing imbalanced-learn for checking version of numpy and sklearn version

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#from sklearn.decomposition import PCA
#pca=PCA(n_components=10)
#xpca=pca.fit_transform(x)
#x=xpca    COULD NOT APPLY PRINCIPLE COMPONENT ANALYSIS AS SHOWING ERROR

# %%
pd.DataFrame(data=x) #PCA REDUCED THE COLUMNS TO 10 BUT SHOWING ERROR
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.963259  0.746940  2.747915 -0.701129 -1.044038  0.617296  2.154071
# 1    2.024557  1.702761  2.029287 -1.369812 -0.626627 -1.463712 -1.438843
# 2   -2.550223  1.358460  1.117144  0.329652  0.430419  0.357078 -0.188398
# 3   -0.180240  0.432328  2.236760 -1.873721 -0.314985  0.535311  0.051865
# 4   -2.996917 -1.221699 -0.034089  0.255799  0.166028 -0.121767 -0.326992
# ..        ...       ...       ...       ...       ...       ...       ...
# 912  1.426894 -1.403149  0.813842  0.585378  2.865076  1.114554  1.254258
# 913  1.658752  0.159575  0.090245  0.814323  1.798916 -2.090907  0.406761
# 914 -1.038620  0.945164 -1.104775  1.827841 -0.325183  0.262503  0.748805
# 915  2.483767 -2.930508 -1.901231  0.013596 -0.949706  1.663642 -0.574050
# 916  2.676821 -1.965297 -2.393540 -0.958359  0.123535  1.045182  1.288948
#
#             7         8         9
# 0    0.314557  0.174045  1.579615
# ...

# %%
x #cOULD NOT BE APPLIED FOR FURTHER ANALYSIS
# Out:
# array([[ 0.96325923,  0.74693968,  2.74791521, ...,  0.31455729,
#          0.17404522,  1.57961493],
#        [ 2.02455688,  1.70276118,  2.02928749, ..., -1.01318567,
#          0.83126739, -0.6654771 ],
#        [-2.55022288,  1.35845977,  1.11714353, ..., -1.06710722,
#         -0.62452279, -1.13625225],
#        ...,
#        [-1.03861997,  0.94516384, -1.1047752 , ...,  0.07136953,
#          0.85989867,  0.50091825],
#        [ 2.48376713, -2.93050757, -1.90123118, ..., -1.08484601,
#          0.08356505,  0.84104728],
#        [ 2.67682124, -1.96529702, -2.39353952, ..., -0.08066237,
#         -1.62514445, -1.5424391 ]])

# %%
x
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.578609 -0.862175  1.114792  0.602126 -0.649389 -2.811212  1.213436
# 1   -0.578609 -0.862175  0.274114  0.602126 -0.649389  0.355718 -1.461374
# 2   -0.578609 -0.862175 -1.407242  0.602126 -0.649389  0.355718  1.213436
# 3   -0.578609 -0.862175 -0.566564  0.602126 -0.649389  0.355718  0.321833
# 4   -0.578609  1.159857 -0.566564  0.602126  1.539910  0.355718  1.213436
# ..        ...       ...       ...       ...       ...       ...       ...
# 912  1.728281 -0.862175  1.114792 -1.660782 -0.649389  0.355718  1.213436
# 913  1.728281 -0.862175  1.955471 -1.660782 -0.649389  0.355718 -0.569770
# 914  1.728281 -0.862175  1.114792  0.602126  1.539910  0.355718  0.321833
# 915  1.728281  1.159857  0.274114  0.602126  1.539910  0.355718  0.321833
# 916  1.728281  1.159857  1.114792 -1.660782  1.539910  0.355718  0.321833
#
#            7         8         9   ...        22        23        24  \
# ...

# %%
from imblearn.over_sampling import SMOTE
smt=SMOTE()
x1,y1=smt.fit_resample(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8260\2831567603.py in <module>
#       1 from imblearn.over_sampling import SMOTE
#       2 smt=SMOTE()
# ----> 3 x1,y1=smt.fit_resample(x, y)
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     206         """
#     207         self._validate_params()
# --> 208         return super().fit_resample(X, y)
#     209
#     210     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#     110         )
#     111
# --> 112         output = self._fit_resample(X, y)
#     113
#     114         y_ = (
#
# ~\anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py in _fit_resample(self, X, y)
#     362
#     363             self.nn_k_.fit(X_class)
# ...
